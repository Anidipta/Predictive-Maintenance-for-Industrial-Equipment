# %%
import pandas as pd
from matplotlib import pyplot
import numpy as np

# %% [markdown]
# ## **Healthy Datas**

# %% [markdown]
# Below are all the sensor readings of healthy gears from loading conditions 0% to 90%.

# %%
h30hz0  = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz0.csv")
h30hz10 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz10.csv")
h30hz20 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz20.csv")
h30hz30 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz30.csv")
h30hz40 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz40.csv")
h30hz50 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz50.csv")
h30hz60 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz60.csv")
h30hz70 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz70.csv")
h30hz80 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz80.csv")
h30hz90 = pd.read_csv("../input/gearbox-fault-diagnosis/Healthy/h30hz90.csv")

# %% [markdown]
# ## **Broken Datas**

# %% [markdown]
# Below are all the sensor readings of broken gears from loading conditions 0% to 90%.

# %%
b30hz0  = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz0.csv")
b30hz10 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz10.csv")
b30hz20 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz20.csv")
b30hz30 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz30.csv")
b30hz40 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz40.csv")
b30hz50 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz50.csv")
b30hz60 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz60.csv")
b30hz70 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz70.csv")
b30hz80 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz80.csv")
b30hz90 = pd.read_csv("../input/gearbox-fault-diagnosis/BrokenTooth/b30hz90.csv")

# %% [markdown]
# Headview of a healthy gear reading from 0% loading

# %%
h30hz0.head()
# Out:
#          a1        a2        a3       a4
# 0  4.636710  0.516978 -3.205940  1.82241
# 1  1.992800  4.184660 -2.740610  2.80436
# 2 -3.764110  0.997335 -1.303090  1.83668
# 3 -4.558710  6.104330 -1.720690  1.72311
# 4  0.575382  0.170980 -0.497967 -1.32895

# %% [markdown]
# ## Add Load and Failure Column for Healthy
#
# ### 0 --> Healhty
# ### 1 --> Broken

# %%
failure = 0

load = 0

h30hz0['load'] = load*np.ones((len(h30hz0.index),1))
failureArray = np.zeros((len(h30hz0.index),1))
h30hz0['failure'] = failureArray

load = 10

h30hz10['load'] = load*np.ones((len(h30hz10.index),1))
failureArray = np.zeros((len(h30hz10.index),1))
h30hz10['failure'] = failureArray

load = 20

h30hz20['load'] = load*np.ones((len(h30hz20.index),1))
failureArray = np.zeros((len(h30hz20.index),1))
h30hz20['failure'] = failureArray

load = 30

h30hz30['load'] = load*np.ones((len(h30hz30.index),1))
failureArray = np.zeros((len(h30hz30.index),1))
h30hz30['failure'] = failureArray

load = 40

h30hz40['load'] = load*np.ones((len(h30hz40.index),1))
failureArray = np.zeros((len(h30hz40.index),1))
h30hz40['failure'] = failureArray

load = 50

h30hz50['load'] = load*np.ones((len(h30hz50.index),1))
failureArray = np.zeros((len(h30hz50.index),1))
h30hz50['failure'] = failureArray

load = 60

h30hz60['load'] = load*np.ones((len(h30hz60.index),1))
failureArray = np.zeros((len(h30hz60.index),1))
h30hz60['failure'] = failureArray

load = 70

h30hz70['load'] = load*np.ones((len(h30hz70.index),1))
failureArray = np.zeros((len(h30hz70.index),1))
h30hz70['failure'] = failureArray

load = 80

h30hz80['load'] = load*np.ones((len(h30hz80.index),1))
failureArray = np.zeros((len(h30hz80.index),1))
h30hz80['failure'] = failureArray

load = 90

h30hz90['load'] = load*np.ones((len(h30hz90.index),1))
failureArray = np.zeros((len(h30hz90.index),1))
h30hz90['failure'] = failureArray

# %% [markdown]
# Checking the new data table with load and healthy condition added

# %%
h30hz90.head()
# Out:
#           a1        a2       a3        a4  load  failure
# 0  -0.788245 -3.722690  1.06864 -0.571325  90.0      0.0
# 1   5.430420 -0.060704 -4.77016  0.599285  90.0      0.0
# 2 -15.461100  1.908580  2.54934 -0.479515  90.0      0.0
# 3  -5.376860 -1.321050  3.01826 -0.360609  90.0      0.0
# 4   8.875310  3.395750 -1.85842  2.412710  90.0      0.0

# %% [markdown]
# ## Add Load and Failure Column for Broken

# %%
failure = 1

load = 0

b30hz0['load'] = load*np.ones((len(b30hz0.index),1))
failureArray = np.ones((len(b30hz0.index),1))
b30hz0['failure'] = failureArray

load = 10 

b30hz10['load'] = load*np.ones((len(b30hz10.index),1))
failureArray = np.ones((len(b30hz10.index),1))
b30hz10['failure'] = failureArray

load = 20 

b30hz20['load'] = load*np.ones((len(b30hz20.index),1))
failureArray = np.ones((len(b30hz20.index),1))
b30hz20['failure'] = failureArray

load = 30 

b30hz30['load'] = load*np.ones((len(b30hz30.index),1))
failureArray = np.ones((len(b30hz30.index),1))
b30hz30['failure'] = failureArray

load = 40 

b30hz40['load'] = load*np.ones((len(b30hz40.index),1))
failureArray = np.ones((len(b30hz40.index),1))
b30hz40['failure'] = failureArray

load = 50 

b30hz50['load'] = load*np.ones((len(b30hz50.index),1))
failureArray = np.ones((len(b30hz50.index),1))
b30hz50['failure'] = failureArray

load = 60 

b30hz60['load'] = load*np.ones((len(b30hz60.index),1))
failureArray = np.ones((len(b30hz60.index),1))
b30hz60['failure'] = failureArray

load = 70 

b30hz70['load'] = load*np.ones((len(b30hz70.index),1))
failureArray = np.ones((len(b30hz70.index),1))
b30hz70['failure'] = failureArray

load = 80 

b30hz80['load'] = load*np.ones((len(b30hz80.index),1))
failureArray = np.ones((len(b30hz80.index),1))
b30hz80['failure'] = failureArray

load = 90 

b30hz90['load'] = load*np.ones((len(b30hz90.index),1))
failureArray = np.ones((len(b30hz90.index),1))
b30hz90['failure'] = failureArray

# %% [markdown]
# Checking the new data table with load and broken condition added

# %%
# check
b30hz90.tail()
# Out:
#              a1       a2        a3        a4  load  failure
# 105723  4.43417 -2.03793 -0.546417  1.181320  90.0      1.0
# 105724  2.90332 -2.82035 -2.486930  0.115640  90.0      1.0
# 105725 -1.61799  1.27861 -6.159510 -1.376230  90.0      1.0
# 105726 -2.01122 -4.02945 -0.082050  0.932847  90.0      1.0
# 105727 -4.43736 -1.97041  3.074570 -3.557610  90.0      1.0

# %% [markdown]
# ## Concat Healty and Broken

# %%
# Broken 

broken_df = pd.concat([b30hz0,b30hz10,b30hz20,b30hz30,b30hz40,b30hz50,b30hz60,b30hz70,b30hz80,b30hz90],axis=0,ignore_index=True)

# %%
# Healthy

healthy_df = pd.concat([h30hz0,h30hz10,h30hz20,h30hz30,h30hz40,h30hz50,h30hz60,h30hz70,h30hz80,h30hz90],axis=0,ignore_index=True)

# %%
# check 
healthy_df.tail()
# Out:
#                 a1       a2       a3        a4  load  failure
# 1015803   0.677448 -3.23441 -1.72599  -3.14302  90.0      0.0
# 1015804 -10.575400  7.72540 -2.18401   2.56965  90.0      0.0
# 1015805  -4.033290  2.57692  1.46843   2.72891  90.0      0.0
# 1015806   1.868670 -5.08940  5.34229  -1.36563  90.0      0.0
# 1015807   7.581480  6.20596 -6.12133  11.54830  90.0      0.0

# %%
# check 
broken_df.tail()
# Out:
#               a1       a2        a3        a4  load  failure
# 1005306  4.43417 -2.03793 -0.546417  1.181320  90.0      1.0
# 1005307  2.90332 -2.82035 -2.486930  0.115640  90.0      1.0
# 1005308 -1.61799  1.27861 -6.159510 -1.376230  90.0      1.0
# 1005309 -2.01122 -4.02945 -0.082050  0.932847  90.0      1.0
# 1005310 -4.43736 -1.97041  3.074570 -3.557610  90.0      1.0

# %%
df= pd.concat([broken_df,healthy_df], axis =0)

# %% [markdown]
# Checking the final aggregated dataset

# %%
df.describe()
# Out:
#                  a1            a2            a3            a4          load  \
# count  2.021119e+06  2.021119e+06  2.021119e+06  2.021119e+06  2.021119e+06
# mean   1.341575e-03  2.589083e-04  4.453338e-03  6.101136e-04  4.564659e+01
# std    6.157919e+00  4.408471e+00  3.963242e+00  4.466629e+00  2.865902e+01
# min   -5.872160e+01 -3.294430e+01 -2.916740e+01 -3.133450e+01  0.000000e+00
# 25%   -3.265495e+00 -2.432110e+00 -2.116310e+00 -2.373490e+00  2.000000e+01
# 50%   -7.987520e-02  9.292100e-02  4.860470e-02  1.161210e-01  5.000000e+01
# 75%    3.135560e+00  2.582300e+00  2.196570e+00  2.483190e+00  7.000000e+01
# max    5.670660e+01  3.092830e+01  2.693890e+01  3.734990e+01  9.000000e+01
#
#             failure
# count  2.021119e+06
# mean   4.974032e-01
# std    4.999934e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in df.columns:
    plt.figure(figsize=(12, 6))
    
    # Boxplot
    plt.subplot(1, 2, 1)
    sns.boxplot(data=df, x=col)
    plt.title(f'Boxplot of {col}')
    
    # Histogram
    plt.subplot(1, 2, 2)
    sns.histplot(data=df[col], kde=True, bins=30)
    plt.title(f'Histogram of {col}')
    
    # Show the plots
    plt.tight_layout()
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, MaxPooling1D, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = df.drop(columns=['failure']).values
y = df['failure'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Train-test split
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Reshape data for CNN (assuming 1D input data)
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %% [markdown]
# ## Adam Optimizer

# %%
model = Sequential([
    Conv1D(64, kernel_size=2, activation='relu', input_shape=(X_train.shape[1], 1)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.25),
    
    Conv1D(128, kernel_size=2, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Use sigmoid for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 4, 64)             192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 4, 64)             256
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 2, 64)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 64)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1, 128)            16512
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 25,793
# Trainable params: 25,409
# Non-trainable params: 384
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=512, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6434 - accuracy: 0.6125 - val_loss: 0.6382 - val_accuracy: 0.6171
# Epoch 2/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6433 - accuracy: 0.6127 - val_loss: 0.6377 - val_accuracy: 0.6177
# Epoch 3/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6432 - accuracy: 0.6130 - val_loss: 0.6384 - val_accuracy: 0.6169
# Epoch 4/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6432 - accuracy: 0.6127 - val_loss: 0.6377 - val_accuracy: 0.6171
# Epoch 5/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6433 - accuracy: 0.6128 - val_loss: 0.6380 - val_accuracy: 0.6175
# Epoch 6/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6432 - accuracy: 0.6127 - val_loss: 0.6377 - val_accuracy: 0.6168
# Epoch 7/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6431 - accuracy: 0.6127 - val_loss: 0.6389 - val_accuracy: 0.6166
# Epoch 8/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6127 - val_loss: 0.6382 - val_accuracy: 0.6174
# Epoch 9/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6432 - accuracy: 0.6126 - val_loss: 0.6376 - val_accuracy: 0.6173
# Epoch 10/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6431 - accuracy: 0.6134 - val_loss: 0.6386 - val_accuracy: 0.6172
# Epoch 11/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6429 - accuracy: 0.6130 - val_loss: 0.6376 - val_accuracy: 0.6171
# Epoch 12/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6432 - accuracy: 0.6130 - val_loss: 0.6374 - val_accuracy: 0.6171
# Epoch 13/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6429 - accuracy: 0.6131 - val_loss: 0.6375 - val_accuracy: 0.6170
# Epoch 14/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6429 - accuracy: 0.6128 - val_loss: 0.6378 - val_accuracy: 0.6167
# Epoch 15/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6127 - val_loss: 0.6375 - val_accuracy: 0.6179
# Epoch 16/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6126 - val_loss: 0.6386 - val_accuracy: 0.6164
# Epoch 17/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6429 - accuracy: 0.6128 - val_loss: 0.6381 - val_accuracy: 0.6161
# Epoch 18/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6129 - val_loss: 0.6384 - val_accuracy: 0.6173
# Epoch 19/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6129 - val_loss: 0.6375 - val_accuracy: 0.6173
# Epoch 20/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6130 - val_loss: 0.6374 - val_accuracy: 0.6179
# Epoch 21/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6129 - val_loss: 0.6376 - val_accuracy: 0.6174
# Epoch 22/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6429 - accuracy: 0.6133 - val_loss: 0.6377 - val_accuracy: 0.6172
# Epoch 23/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6130 - val_loss: 0.6371 - val_accuracy: 0.6180
# Epoch 24/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6428 - accuracy: 0.6134 - val_loss: 0.6375 - val_accuracy: 0.6174
# Epoch 25/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6430 - accuracy: 0.6128 - val_loss: 0.6375 - val_accuracy: 0.6174
# Epoch 26/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6429 - accuracy: 0.6132 - val_loss: 0.6375 - val_accuracy: 0.6181
# Epoch 27/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6428 - accuracy: 0.6130 - val_loss: 0.6377 - val_accuracy: 0.6179
# Epoch 28/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6429 - accuracy: 0.6133 - val_loss: 0.6377 - val_accuracy: 0.6177
# Epoch 29/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6426 - accuracy: 0.6134 - val_loss: 0.6371 - val_accuracy: 0.6173
# Epoch 30/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6428 - accuracy: 0.6131 - val_loss: 0.6387 - val_accuracy: 0.6177

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 20843/20843 [==============================] - 33s 2ms/step - loss: 0.6387 - accuracy: 0.6177
# Test Loss: 0.6387219429016113
# Test Accuracy: 0.6177204251289368

# %%
# Save the model
model.save('cnn_failure_model.h5')

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Confusion Matrix
y_pred = (model.predict(X_test) > 0.5).astype("int32")  # Binary classification threshold
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No Failure', 'Failure'], yticklabels=['No Failure', 'Failure'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['No Failure', 'Failure']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   No Failure       0.66      0.48      0.56    334937
#      Failure       0.59      0.75      0.66    332033
#
#     accuracy                           0.62    666970
#    macro avg       0.63      0.62      0.61    666970
# weighted avg       0.63      0.62      0.61    666970

# %% [markdown]
# ## SMORMS3 Optimizer

# %%
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense

# Define the model
model = Sequential([
    Conv1D(64, kernel_size=2, activation='relu', input_shape=(X_train.shape[1], 1)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.25),

    Conv1D(128, kernel_size=2, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Use sigmoid for binary classification
])

# Define the SMORMS3 optimizer
smorms3 = tfa.optimizers.SGDW(learning_rate=0.001, weight_decay=0.0, momentum=0.0, nesterov=False)

# Compile the model
model.compile(optimizer=smorms3, loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 4, 64)             192
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 64)             256
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 2, 64)             0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 64)             0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1, 128)            16512
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 128)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 25,793
# Trainable params: 25,409
# Non-trainable params: 384
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=512, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 2645/2645 [==============================] - 14s 5ms/step - loss: 0.8383 - accuracy: 0.5103 - val_loss: 0.6640 - val_accuracy: 0.5847
# Epoch 2/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.7140 - accuracy: 0.5372 - val_loss: 0.6635 - val_accuracy: 0.5914
# Epoch 3/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6886 - accuracy: 0.5466 - val_loss: 0.6635 - val_accuracy: 0.5934
# Epoch 4/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6807 - accuracy: 0.5532 - val_loss: 0.6632 - val_accuracy: 0.5946
# Epoch 5/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6766 - accuracy: 0.5589 - val_loss: 0.6621 - val_accuracy: 0.5954
# Epoch 6/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6740 - accuracy: 0.5638 - val_loss: 0.6608 - val_accuracy: 0.5961
# Epoch 7/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6723 - accuracy: 0.5675 - val_loss: 0.6596 - val_accuracy: 0.5967
# Epoch 8/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6705 - accuracy: 0.5703 - val_loss: 0.6585 - val_accuracy: 0.5973
# Epoch 9/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6698 - accuracy: 0.5711 - val_loss: 0.6577 - val_accuracy: 0.5978
# Epoch 10/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6688 - accuracy: 0.5730 - val_loss: 0.6569 - val_accuracy: 0.5978
# Epoch 11/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6676 - accuracy: 0.5759 - val_loss: 0.6562 - val_accuracy: 0.5982
# Epoch 12/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6674 - accuracy: 0.5756 - val_loss: 0.6556 - val_accuracy: 0.5984
# Epoch 13/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6665 - accuracy: 0.5772 - val_loss: 0.6553 - val_accuracy: 0.5983
# Epoch 14/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6657 - accuracy: 0.5791 - val_loss: 0.6551 - val_accuracy: 0.5982
# Epoch 15/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6656 - accuracy: 0.5795 - val_loss: 0.6545 - val_accuracy: 0.5988
# Epoch 16/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6648 - accuracy: 0.5809 - val_loss: 0.6542 - val_accuracy: 0.5991
# Epoch 17/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6645 - accuracy: 0.5813 - val_loss: 0.6539 - val_accuracy: 0.5990
# Epoch 18/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6637 - accuracy: 0.5825 - val_loss: 0.6536 - val_accuracy: 0.5990
# Epoch 19/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6637 - accuracy: 0.5832 - val_loss: 0.6532 - val_accuracy: 0.5996
# Epoch 20/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6631 - accuracy: 0.5833 - val_loss: 0.6532 - val_accuracy: 0.5993
# Epoch 21/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6630 - accuracy: 0.5841 - val_loss: 0.6529 - val_accuracy: 0.5996
# Epoch 22/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6626 - accuracy: 0.5845 - val_loss: 0.6527 - val_accuracy: 0.5997
# Epoch 23/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6627 - accuracy: 0.5851 - val_loss: 0.6524 - val_accuracy: 0.5998
# Epoch 24/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6621 - accuracy: 0.5850 - val_loss: 0.6522 - val_accuracy: 0.6001
# Epoch 25/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6617 - accuracy: 0.5864 - val_loss: 0.6522 - val_accuracy: 0.6000
# Epoch 26/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6617 - accuracy: 0.5871 - val_loss: 0.6518 - val_accuracy: 0.6003
# Epoch 27/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6613 - accuracy: 0.5870 - val_loss: 0.6520 - val_accuracy: 0.5999
# Epoch 28/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6611 - accuracy: 0.5874 - val_loss: 0.6517 - val_accuracy: 0.6002
# Epoch 29/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6607 - accuracy: 0.5878 - val_loss: 0.6516 - val_accuracy: 0.6002
# Epoch 30/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6609 - accuracy: 0.5875 - val_loss: 0.6513 - val_accuracy: 0.6005

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 20843/20843 [==============================] - 33s 2ms/step - loss: 0.6513 - accuracy: 0.6005
# Test Loss: 0.651321530342102
# Test Accuracy: 0.6004632711410522

# %%
# Save the model
model.save('cnn_smorms3_model.h5')

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Confusion Matrix
y_pred = (model.predict(X_test) > 0.5).astype("int32")  # Binary classification threshold
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No Failure', 'Failure'], yticklabels=['No Failure', 'Failure'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['No Failure', 'Failure']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   No Failure       0.71      0.35      0.47    334937
#      Failure       0.57      0.85      0.68    332033
#
#     accuracy                           0.60    666970
#    macro avg       0.64      0.60      0.57    666970
# weighted avg       0.64      0.60      0.57    666970

# %% [markdown]
# ## RMSProp Optimizer

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense

# Define the model
model = Sequential([
    Conv1D(64, kernel_size=2, activation='relu', input_shape=(X_train.shape[1], 1)),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.25),

    Conv1D(128, kernel_size=2, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Use sigmoid for binary classification
])

# Define the RMSprop optimizer
rmsprop = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-07)

# Compile the model
model.compile(optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 4, 64)             192
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 64)             256
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 2, 64)             0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2, 64)             0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1, 128)            16512
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1, 128)            512
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 1, 128)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 25,793
# Trainable params: 25,409
# Non-trainable params: 384
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=512, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 2645/2645 [==============================] - 15s 5ms/step - loss: 0.6804 - accuracy: 0.5824 - val_loss: 0.6425 - val_accuracy: 0.6109
# Epoch 2/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6481 - accuracy: 0.6072 - val_loss: 0.6424 - val_accuracy: 0.6128
# Epoch 3/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6470 - accuracy: 0.6087 - val_loss: 0.6407 - val_accuracy: 0.6141
# Epoch 4/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6461 - accuracy: 0.6097 - val_loss: 0.6404 - val_accuracy: 0.6139
# Epoch 5/30
# 2645/2645 [==============================] - 14s 5ms/step - loss: 0.6457 - accuracy: 0.6103 - val_loss: 0.6399 - val_accuracy: 0.6152
# Epoch 6/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6454 - accuracy: 0.6097 - val_loss: 0.6399 - val_accuracy: 0.6153
# Epoch 7/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6454 - accuracy: 0.6105 - val_loss: 0.6399 - val_accuracy: 0.6146
# Epoch 8/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6451 - accuracy: 0.6106 - val_loss: 0.6389 - val_accuracy: 0.6159
# Epoch 9/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6449 - accuracy: 0.6109 - val_loss: 0.6389 - val_accuracy: 0.6162
# Epoch 10/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6445 - accuracy: 0.6110 - val_loss: 0.6385 - val_accuracy: 0.6163
# Epoch 11/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6447 - accuracy: 0.6115 - val_loss: 0.6387 - val_accuracy: 0.6164
# Epoch 12/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6449 - accuracy: 0.6100 - val_loss: 0.6389 - val_accuracy: 0.6163
# Epoch 13/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6444 - accuracy: 0.6114 - val_loss: 0.6394 - val_accuracy: 0.6154
# Epoch 14/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6446 - accuracy: 0.6112 - val_loss: 0.6387 - val_accuracy: 0.6164
# Epoch 15/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6447 - accuracy: 0.6112 - val_loss: 0.6384 - val_accuracy: 0.6163
# Epoch 16/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6439 - accuracy: 0.6119 - val_loss: 0.6403 - val_accuracy: 0.6153
# Epoch 17/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6445 - accuracy: 0.6111 - val_loss: 0.6387 - val_accuracy: 0.6164
# Epoch 18/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6442 - accuracy: 0.6111 - val_loss: 0.6389 - val_accuracy: 0.6163
# Epoch 19/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6445 - accuracy: 0.6114 - val_loss: 0.6384 - val_accuracy: 0.6169
# Epoch 20/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6443 - accuracy: 0.6114 - val_loss: 0.6390 - val_accuracy: 0.6170
# Epoch 21/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6446 - accuracy: 0.6113 - val_loss: 0.6390 - val_accuracy: 0.6160
# Epoch 22/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6442 - accuracy: 0.6112 - val_loss: 0.6393 - val_accuracy: 0.6165
# Epoch 23/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6443 - accuracy: 0.6118 - val_loss: 0.6393 - val_accuracy: 0.6164
# Epoch 24/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6440 - accuracy: 0.6119 - val_loss: 0.6383 - val_accuracy: 0.6165
# Epoch 25/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6440 - accuracy: 0.6116 - val_loss: 0.6393 - val_accuracy: 0.6156
# Epoch 26/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6442 - accuracy: 0.6112 - val_loss: 0.6387 - val_accuracy: 0.6170
# Epoch 27/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6443 - accuracy: 0.6118 - val_loss: 0.6384 - val_accuracy: 0.6161
# Epoch 28/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6438 - accuracy: 0.6123 - val_loss: 0.6383 - val_accuracy: 0.6168
# Epoch 29/30
# 2645/2645 [==============================] - 14s 5ms/step - loss: 0.6439 - accuracy: 0.6113 - val_loss: 0.6391 - val_accuracy: 0.6159
# Epoch 30/30
# 2645/2645 [==============================] - 13s 5ms/step - loss: 0.6438 - accuracy: 0.6116 - val_loss: 0.6389 - val_accuracy: 0.6165

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 20843/20843 [==============================] - 34s 2ms/step - loss: 0.6389 - accuracy: 0.6165
# Test Loss: 0.638936460018158
# Test Accuracy: 0.6165044903755188

# %%
# Save the model
model.save('cnn_rms_model.h5')

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Confusion Matrix
y_pred = (model.predict(X_test) > 0.5).astype("int32")  # Binary classification threshold
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No Failure', 'Failure'], yticklabels=['No Failure', 'Failure'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['No Failure', 'Failure']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   No Failure       0.68      0.45      0.54    334937
#      Failure       0.59      0.78      0.67    332033
#
#     accuracy                           0.62    666970
#    macro avg       0.63      0.62      0.61    666970
# weighted avg       0.63      0.62      0.61    666970
